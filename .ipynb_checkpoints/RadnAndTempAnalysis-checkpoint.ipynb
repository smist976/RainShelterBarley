# %% [markdown]
# ##Bring in libraries and dataframes and set indexes

# %%
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
AllData=pd.read_csv('K:\Rainshelter\Barley_2014_15\LoggedData\RainShelterBeta_Energy.dat', #specify file path for data to read in
                         parse_dates=True, #tell the function to parse date columns to datetime formats
                         dayfirst=True, #tell the function that the day is before the year in the data i.e format='%d/%m/%Y %H:%M'
                         skiprows = [0,2,3], #leave out rows 1, 3 and 4 which have redundant information
                         index_col = 0, #Use the first column, which is Date, as an index
                         na_values = 'NAN')
AllDataIndex=pd.read_csv('C:\GitHubRepos\RainShelterBarley\RadiationAndTempIndex.csv',
                         index_col = 0)
AllDataTransposed = AllData.transpose()
AllDataIndexed = pd.concat([AllDataIndex,AllDataTransposed], axis=1)
AllDataIndexed.index.name='ColumnHeader'
AllDataIndexed.set_index(['Measurement','Irrigation','Cultivar','Treatment','Units','Summary','Plot','Column','Block'], 
                         append=True, inplace=True)
Data=AllDataIndexed.transpose()
Data.sort(inplace=True)
DataMeans = Data.groupby(level=['Measurement','Irrigation', 'Cultivar'],axis=1).mean()

# %% [markdown]
# ## Set time slice to graph

# %%
from datetime import timedelta #Import function needed for doing date deltas 
EndDate = Data.index.max(axis=0)  #Set end of series as most recent date in file
EndDateString = EndDate.strftime("%Y-%m-%d")  #Turn this to a string
PlotDuration = 1                              #Set the duration that you want to graph for
StartDate = EndDate - timedelta(weeks=PlotDuration)       #Set start date the specified duration before the end date 
StartDateString = StartDate.strftime("%Y-%m-%d")           #Turn that into a string

# %% [markdown]
# ##Graph met data the check

# %%
DataMeans.ix[StartDateString:,['BatteryVoltage','AirTemperature','IncomingRadnKW','Leafwetness','PannelTemperature','Rainfall','RelativeHumidity','Windspeed']].plot(subplots=True, figsize=(18, 30),
                    style='r-',
                    linewidth = 2)
# Out:
# array([<matplotlib.axes.AxesSubplot object at 0x000000000D0EF898>,
#        <matplotlib.axes.AxesSubplot object at 0x000000000D196B00>,
#        <matplotlib.axes.AxesSubplot object at 0x000000000D227E10>,
#        <matplotlib.axes.AxesSubplot object at 0x000000000D256860>,
#        <matplotlib.axes.AxesSubplot object at 0x0000000010474748>,
#        <matplotlib.axes.AxesSubplot object at 0x000000000D1C1198>,
#        <matplotlib.axes.AxesSubplot object at 0x00000000104B3940>,
#        <matplotlib.axes.AxesSubplot object at 0x00000000104D5828>], dtype=object)

# %% [markdown]
# ##Graph all sensors to check for anomolies

# %%
Data.ix[StartDateString:,[X for X in Data.columns if 'HeatFlux' in X]].plot(legend=False,figsize=(18,10))

# %%
Data.ix[StartDateString:,[X for X in Data.columns if 'IR_SurfaceTemp' in X]].plot(legend=False, figsize=(18,10))

# %%
Data.ix[StartDateString:,[X for X in Data.columns if 'IR_SensorBodyTemp' in X]].plot(legend=False, figsize=(18,10))

# %%
Data.ix[StartDateString::,[X for X in Data.columns if 'SoilTemp15cm' in X]].plot(legend=False, figsize=(18,10))

# %%
Data.ix[StartDateString:,[X for X in Data.columns if 'BelowCanopyPAR' in X]].plot(legend=False, figsize=(18,10))

# %%
Data.ix[StartDateString:,[X for X in Data.columns if 'SurfaceSoilTemp' in X]].plot(legend=False, figsize=(18,10))

# 2014-11-11 14:10:00            24.8150  24.8550  25.3675  24.9025  24.9750
# 2014-11-11 14:15:00            24.6025  24.7075  25.2125  24.7275  24.8775
# 2014-11-11 14:20:00            24.1325  24.2225  24.7575  24.2225  24.4100
# 2014-11-11 14:25:00            23.8950  23.9750  24.6175  24.0975  24.1550
# 2014-11-11 14:30:00            23.4800  23.6200  24.1625  23.7075  23.7500
# 2014-11-11 14:35:00            23.2425  23.3325  23.9125  23.4175  23.4350
# 2014-11-11 14:40:00            23.0650  23.1550  23.6650  23.2350  23.2825
# 2014-11-11 14:45:00            22.7750  22.9925  23.3800  22.9350  23.1625
# 2014-11-11 14:50:00            21.3675  21.4425  21.8225  21.4200  21.6900
# 2014-11-11 14:55:00            20.7175  20.7650  21.1500  20.7525  20.9475
#
# Measurement                   IR_SurfaceTemp
# Irrigation                              High               Low
# Cultivar               Omaka            Dash    Omaka     Dash
# 2014-11-11 14:10:00  25.4625         35.0325  29.0075  38.2725 ...
# 2014-11-11 14:15:00  25.2875         35.8450  29.3375  39.1475 ...
# 2014-11-11 14:20:00  24.7800         35.0400  29.0100  38.3325 ...
# 2014-11-11 14:25:00  24.5475         35.0925  29.0825  38.2350 ...
# 2014-11-11 14:30:00  24.1675         33.5050  27.7375  36.5525 ...
# 2014-11-11 14:35:00  23.9575         34.1775  28.1475  37.1650 ...
# 2014-11-11 14:40:00  23.7900         33.4775  27.9625  36.6550 ...
# 2014-11-11 14:45:00  23.6225         31.4200  26.4625  34.3150 ...
# 2014-11-11 14:50:00  22.0125         27.7950  23.5675  30.3575 ...
# 2014-11-11 14:55:00  21.2600         28.7800  24.5525  31.0250 ...
#
# [10 rows x 57 columns]

# %% [markdown]
# ##Graph treatment means

# %%
DataMeans.ix[StartDateString:,['IncomingRadnKW','ReflectedRadnKW']].plot(figsize=(18,10))

# %%
DataMeans.ix[StartDateString:,['PannelTemperature','AirTemperature','SurfaceSoilTemp','SoilTemp15cm']].plot(figsize=(18,10))

# %%
DataMeans.ix[StartDateString:,['IR_SurfaceTemp','SurfaceSoilTemp']].plot(figsize=(18,10))

# %%
DataMeans.ix[StartDateString:,['AboveCanopyPAR','BelowCanopyPAR']].plot(figsize=(18,10))

# %%
DataMeans.ix[StartDateString:,'HeatFlux'].plot(figsize=(18,10))

# %% [markdown]
# ##Calculate and graph radiation interception and reflection

# %%
FractPARint = DataMeans.ix[StartDateString:,'BelowCanopyPAR'] / DataMeans.ix[StartDateString:,0] 
FractPARint.plot(figsize=(18,10),
                 ylim=(0,1))

# %%
FractRadRefl = DataMeans.ix[StartDateString:,'ReflectedRadnKW'] / Data.ix[StartDateString:,84] 
FractRadRefl.plot(figsize=(18,10),
                 ylim=(0,.4))
